# %% [markdown]
# <a href="https://colab.research.google.com/github/wx2123/SAS-to-R/blob/main/sascode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Step 1: Download the binary SAS dataset directly from the GitHub repository
# Corrected URL to download the raw 'loan_data.sas7bdat' file
# !wget https://raw.githubusercontent.com/wx2123/SAS-to-R/master/loan_data.sas7bdat

# Step 2: Read the downloaded local file into a pandas DataFrame
# We include encoding='latin1' to ensure text fields parse correctly
df = pd.read_sas('loan_data.sas7bdat', format='sas7bdat', encoding='latin1')

# Step 3: View the data
print(df.head())
# Out:
# --2026-09-07 18:06:30--  https://raw.githubusercontent.com/wx2123/SAS-to-R/master/loan_data.sas7bdat
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 262144 (256K) [application/octet-stream]
# Saving to: ‘loan_data.sas7bdat’
#
# loan_data.sas7bdat  100%[===================>] 256.00K  --.-KB/s    in 0.004s
#
# 2026-09-07 18:06:32 (59.0 MB/s) - ‘loan_data.sas7bdat’ saved [262144/262144]
#
#    customer_id   age    income  credit_score
# 0       1001.0  35.0   75000.0         720.0
# 1       1002.0  42.0   92000.0           NaN
# 2       1003.0  28.0   58000.0         680.0
# 3       1004.0  51.0  115000.0         790.0
# 4       1005.0  39.0   83000.0         710.0
